# %% [markdown]
# <a href="https://colab.research.google.com/github/snehanshastri/BIS/blob/main/Gene_Expression_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import numpy as np

def sphere_function(x):
    """
    Sphere function to be optimized.
    Minimum value at (0, 0, ..., 0) with f(0) = 0
    """
    return sum(xi ** 2 for xi in x)

def initialize_population(pop_size, num_genes, bounds):
    """
    Generate an initial population of random genetic sequences.
    """
    population = []
    for _ in range(pop_size):
        genes = [random.uniform(bounds[0], bounds[1]) for _ in range(num_genes)]
        population.append(genes)
    return population

def evaluate_fitness(population):
    """
    Evaluate the fitness of each genetic sequence in the population.
    Fitness is the inverse of the sphere function (minimization problem).
    """
    fitness = []
    for genes in population:
        value = sphere_function(genes)
        fitness.append(1 / (1 + value))  # Avoid division by zero
    return fitness

def selection(population, fitness, num_parents):
    """
    Select individuals based on their fitness using roulette wheel selection.
    """
    selected = []
    total_fitness = sum(fitness)
    probabilities = [f / total_fitness for f in fitness]
    for _ in range(num_parents):
        selected.append(random.choices(population, weights=probabilities, k=1)[0])
    return selected

def crossover(parents, num_offspring):
    """
    Perform crossover between pairs of parents to produce offspring.
    Single-point crossover is used.
    """
    offspring = []
    for _ in range(num_offspring):
        p1, p2 = random.sample(parents, 2)
        crossover_point = random.randint(1, len(p1) - 1)
        child = p1[:crossover_point] + p2[crossover_point:]
        offspring.append(child)
    return offspring

def mutation(offspring, mutation_rate, bounds):
    """
    Apply mutation to the offspring to introduce variability.
    Mutation randomly modifies genes based on the mutation rate.
    """
    for i in range(len(offspring)):
        for j in range(len(offspring[i])):
            if random.random() < mutation_rate:
                offspring[i][j] = random.uniform(bounds[0], bounds[1])
    return offspring

def gene_expression(population):
    """
    Gene expression step: Here, the genetic sequence itself acts as the solution.
    Returns the population as functional solutions.
    """
    return population

def find_best_solution(population):
    """
    Find the best solution in the population based on the sphere function.
    """
    best_solution = min(population, key=sphere_function)
    best_value = sphere_function(best_solution)
    return best_solution, best_value

def gene_expression_algorithm(pop_size=50, num_genes=10, bounds=(-5, 5), mutation_rate=0.1,
                              crossover_rate=0.8, generations=100):
    """
    Main function to execute the Gene Expression Algorithm.
    """
    # Step 1: Initialize the population
    population = initialize_population(pop_size, num_genes, bounds)
    num_parents = int(pop_size * crossover_rate)
    num_offspring = pop_size - num_parents

    for generation in range(generations):
        # Step 2: Evaluate fitness
        fitness = evaluate_fitness(population)

        # Step 3: Selection
        parents = selection(population, fitness, num_parents)

        # Step 4: Crossover
        offspring = crossover(parents, num_offspring)

        # Step 5: Mutation
        offspring = mutation(offspring, mutation_rate, bounds)

        # Step 6: Gene Expression
        population = gene_expression(parents + offspring)

        # Step 7: Find the best solution in the current generation
        best_solution, best_value = find_best_solution(population)
        print(f"Generation {generation + 1}: Best Value = {best_value:.5f}")

    # Output the final best solution
    best_solution, best_value = find_best_solution(population)
    print("\nFinal Best Solution:")
    print(f"Genes: {best_solution}, Value: {best_value:.5f}")

if __name__ == "__main__":
    gene_expression_algorithm(pop_size=50, num_genes=10, bounds=(-5, 5), mutation_rate=0.1,
                              crossover_rate=0.8, generations=500)
# Out:
# Generation 1: Best Value = 29.24526
# Generation 2: Best Value = 29.24526
# Generation 3: Best Value = 29.24526
# Generation 4: Best Value = 20.07386
# Generation 5: Best Value = 20.07386
# Generation 6: Best Value = 20.07386
# Generation 7: Best Value = 20.07386
# Generation 8: Best Value = 20.07386
# Generation 9: Best Value = 20.07386
# Generation 10: Best Value = 20.07386
# Generation 11: Best Value = 20.07386
# Generation 12: Best Value = 4.47912
# Generation 13: Best Value = 4.47912
# Generation 14: Best Value = 3.81217
# Generation 15: Best Value = 3.81217
# Generation 16: Best Value = 3.81217
# Generation 17: Best Value = 3.81217
# Generation 18: Best Value = 3.81217
# Generation 19: Best Value = 3.81217
# Generation 20: Best Value = 4.16462
# Generation 21: Best Value = 4.16462
# Generation 22: Best Value = 4.16462
# Generation 23: Best Value = 2.74978
# Generation 24: Best Value = 2.74978
# Generation 25: Best Value = 2.74978
# Generation 26: Best Value = 2.74978
# Generation 27: Best Value = 2.74978
# Generation 28: Best Value = 2.74978
# Generation 29: Best Value = 2.74978
# Generation 30: Best Value = 2.74978
# Generation 31: Best Value = 2.74978
# Generation 32: Best Value = 2.74978
# Generation 33: Best Value = 2.74978
# Generation 34: Best Value = 2.52197
# Generation 35: Best Value = 2.38119
# Generation 36: Best Value = 2.38119
# Generation 37: Best Value = 2.38119
# Generation 38: Best Value = 2.24427
# Generation 39: Best Value = 2.43725
# Generation 40: Best Value = 2.52197
# Generation 41: Best Value = 2.36857
# Generation 42: Best Value = 2.45776
# Generation 43: Best Value = 2.45776
# Generation 44: Best Value = 2.45776
# Generation 45: Best Value = 2.52197
# Generation 46: Best Value = 2.52197
# Generation 47: Best Value = 2.74978
# Generation 48: Best Value = 2.74978
# Generation 49: Best Value = 2.73253
# Generation 50: Best Value = 2.52197
# Generation 51: Best Value = 2.06881
# Generation 52: Best Value = 2.52197
# Generation 53: Best Value = 2.52197
# Generation 54: Best Value = 2.52197
# Generation 55: Best Value = 2.52197
# Generation 56: Best Value = 2.43081
# Generation 57: Best Value = 2.74391
# Generation 58: Best Value = 2.74391
# Generation 59: Best Value = 2.74391
# Generation 60: Best Value = 2.74391
# Generation 61: Best Value = 2.33793
# Generation 62: Best Value = 2.33793
# Generation 63: Best Value = 2.33793
# Generation 64: Best Value = 2.33793
# Generation 65: Best Value = 2.33793
# Generation 66: Best Value = 2.33793
# Generation 67: Best Value = 2.33793
# Generation 68: Best Value = 2.33793
# Generation 69: Best Value = 2.33793
# Generation 70: Best Value = 2.33793
# Generation 71: Best Value = 2.33793
# Generation 72: Best Value = 2.33793
# Generation 73: Best Value = 2.33793
# Generation 74: Best Value = 2.33793
# Generation 75: Best Value = 2.33793
# Generation 76: Best Value = 2.33793
# Generation 77: Best Value = 2.33793
# Generation 78: Best Value = 2.33793
# Generation 79: Best Value = 2.32372
# Generation 80: Best Value = 1.96751
# Generation 81: Best Value = 2.00689
# Generation 82: Best Value = 1.84961
# Generation 83: Best Value = 2.00689
# Generation 84: Best Value = 2.00689
# Generation 85: Best Value = 2.00689
# Generation 86: Best Value = 2.00689
# Generation 87: Best Value = 1.91721
# Generation 88: Best Value = 1.66956
# Generation 89: Best Value = 2.00689
# Generation 90: Best Value = 2.00689
# Generation 91: Best Value = 2.00689
# Generation 92: Best Value = 2.00689
# Generation 93: Best Value = 2.00308
# Generation 94: Best Value = 2.00308
# Generation 95: Best Value = 2.00308
# Generation 96: Best Value = 2.00308
# Generation 97: Best Value = 2.00689
# Generation 98: Best Value = 2.00689
# Generation 99: Best Value = 2.00689
# Generation 100: Best Value = 2.00689
# Generation 101: Best Value = 1.79222
# Generation 102: Best Value = 2.00689
# Generation 103: Best Value = 2.00689
# Generation 104: Best Value = 2.00689
# Generation 105: Best Value = 2.00689
# Generation 106: Best Value = 2.00689
# Generation 107: Best Value = 2.00689
# Generation 108: Best Value = 2.00689
# Generation 109: Best Value = 2.00689
# Generation 110: Best Value = 1.95866
# Generation 111: Best Value = 1.95866
# Generation 112: Best Value = 1.93303
# Generation 113: Best Value = 2.00689
# Generation 114: Best Value = 2.00689
# Generation 115: Best Value = 2.00689
# Generation 116: Best Value = 2.00689
# Generation 117: Best Value = 2.00689
# Generation 118: Best Value = 2.00689
# Generation 119: Best Value = 2.00689
# Generation 120: Best Value = 2.00689
# Generation 121: Best Value = 2.00469
# Generation 122: Best Value = 2.00469
# Generation 123: Best Value = 2.00469
# Generation 124: Best Value = 2.00469
# Generation 125: Best Value = 1.96231
# Generation 126: Best Value = 1.96231
# Generation 127: Best Value = 1.96231
# Generation 128: Best Value = 2.00469
# Generation 129: Best Value = 1.28831
# Generation 130: Best Value = 1.94648
# Generation 131: Best Value = 1.94648
# Generation 132: Best Value = 2.00689
# Generation 133: Best Value = 1.45460
# Generation 134: Best Value = 1.85485
# Generation 135: Best Value = 1.85485
# Generation 136: Best Value = 1.85485
# Generation 137: Best Value = 1.85485
# Generation 138: Best Value = 1.85485
# Generation 139: Best Value = 1.85485
# Generation 140: Best Value = 1.85485
# Generation 141: Best Value = 1.85485
# Generation 142: Best Value = 1.85485
# Generation 143: Best Value = 1.85485
# Generation 144: Best Value = 1.85485
# Generation 145: Best Value = 1.85485
# Generation 146: Best Value = 1.85485
# Generation 147: Best Value = 1.85485
# Generation 148: Best Value = 1.69883
# Generation 149: Best Value = 1.85485
# Generation 150: Best Value = 1.85485
# Generation 151: Best Value = 1.85485
# Generation 152: Best Value = 1.85485
# Generation 153: Best Value = 1.85485
# Generation 154: Best Value = 1.85485
# Generation 155: Best Value = 1.85485
# Generation 156: Best Value = 1.76426
# Generation 157: Best Value = 1.76426
# Generation 158: Best Value = 1.43904
# Generation 159: Best Value = 1.43904
# Generation 160: Best Value = 1.43904
# Generation 161: Best Value = 1.43904
# Generation 162: Best Value = 1.43904
# Generation 163: Best Value = 1.43904
# Generation 164: Best Value = 1.43904
# Generation 165: Best Value = 1.43904
# Generation 166: Best Value = 1.43036
# Generation 167: Best Value = 1.43036
# Generation 168: Best Value = 1.30092
# Generation 169: Best Value = 1.30092
# Generation 170: Best Value = 1.05480
# Generation 171: Best Value = 1.05480
# Generation 172: Best Value = 1.05480
# Generation 173: Best Value = 1.05480
# Generation 174: Best Value = 1.05480
# Generation 175: Best Value = 1.05480
# Generation 176: Best Value = 1.05480
# Generation 177: Best Value = 1.05480
# Generation 178: Best Value = 1.05480
# Generation 179: Best Value = 1.05480
# Generation 180: Best Value = 1.05480
# Generation 181: Best Value = 1.00179
# Generation 182: Best Value = 1.05480
# Generation 183: Best Value = 1.05480
# Generation 184: Best Value = 1.05480
# Generation 185: Best Value = 1.05480
# Generation 186: Best Value = 1.05480
# Generation 187: Best Value = 1.01901
# Generation 188: Best Value = 0.84399
# Generation 189: Best Value = 0.82924
# Generation 190: Best Value = 0.82924
# Generation 191: Best Value = 0.82924
# Generation 192: Best Value = 0.82924
# Generation 193: Best Value = 0.81003
# Generation 194: Best Value = 0.81003
# Generation 195: Best Value = 0.81003
# Generation 196: Best Value = 0.81003
# Generation 197: Best Value = 0.81003
# Generation 198: Best Value = 0.65421
# Generation 199: Best Value = 0.82924
# Generation 200: Best Value = 0.82924
# Generation 201: Best Value = 0.56025
# Generation 202: Best Value = 0.56025
# Generation 203: Best Value = 0.56025
# Generation 204: Best Value = 0.82924
# Generation 205: Best Value = 0.82924
# Generation 206: Best Value = 0.82924
# Generation 207: Best Value = 0.82924
# Generation 208: Best Value = 0.82924
# Generation 209: Best Value = 0.82924
# Generation 210: Best Value = 0.82924
# Generation 211: Best Value = 0.82924
# Generation 212: Best Value = 0.82924
# Generation 213: Best Value = 0.82924
# Generation 214: Best Value = 0.82924
# Generation 215: Best Value = 0.82924
# Generation 216: Best Value = 0.82924
# Generation 217: Best Value = 0.82924
# Generation 218: Best Value = 0.82924
# Generation 219: Best Value = 0.82924
# Generation 220: Best Value = 0.82924
# Generation 221: Best Value = 0.82924
# Generation 222: Best Value = 0.82924
# Generation 223: Best Value = 0.82924
# Generation 224: Best Value = 0.82924
# Generation 225: Best Value = 0.82924
# Generation 226: Best Value = 0.82924
# Generation 227: Best Value = 0.78669
# Generation 228: Best Value = 0.78669
# Generation 229: Best Value = 0.78248
# Generation 230: Best Value = 0.75747
# Generation 231: Best Value = 0.75747
# Generation 232: Best Value = 0.75747
# Generation 233: Best Value = 0.82650
# Generation 234: Best Value = 0.82650
# Generation 235: Best Value = 0.74210
# Generation 236: Best Value = 0.53784
# Generation 237: Best Value = 0.52848
# Generation 238: Best Value = 0.52848
# Generation 239: Best Value = 0.52848
# Generation 240: Best Value = 0.53784
# Generation 241: Best Value = 0.53784
# Generation 242: Best Value = 0.53784
# Generation 243: Best Value = 0.53784
# Generation 244: Best Value = 0.53784
# Generation 245: Best Value = 0.53784
# Generation 246: Best Value = 0.48863
# Generation 247: Best Value = 0.48863
# Generation 248: Best Value = 0.53784
# Generation 249: Best Value = 0.53784
# Generation 250: Best Value = 0.53784
# Generation 251: Best Value = 0.40045
# Generation 252: Best Value = 0.40045
# Generation 253: Best Value = 0.40045
# Generation 254: Best Value = 0.40045
# Generation 255: Best Value = 0.40045
# Generation 256: Best Value = 0.40045
# Generation 257: Best Value = 0.40045
# Generation 258: Best Value = 0.40045
# Generation 259: Best Value = 0.40045
# Generation 260: Best Value = 0.40045
# Generation 261: Best Value = 0.36066
# Generation 262: Best Value = 0.40045
# Generation 263: Best Value = 0.40045
# Generation 264: Best Value = 0.40045
# Generation 265: Best Value = 0.40045
# Generation 266: Best Value = 0.40045
# Generation 267: Best Value = 0.40045
# Generation 268: Best Value = 0.40045
# Generation 269: Best Value = 0.40045
# Generation 270: Best Value = 0.40045
# Generation 271: Best Value = 0.40045
# Generation 272: Best Value = 0.40045
# Generation 273: Best Value = 0.40045
# Generation 274: Best Value = 0.40045
# Generation 275: Best Value = 0.40045
# Generation 276: Best Value = 0.53784
# Generation 277: Best Value = 0.53784
# Generation 278: Best Value = 0.53784
# Generation 279: Best Value = 0.53784
# Generation 280: Best Value = 0.53784
# Generation 281: Best Value = 0.53784
# Generation 282: Best Value = 0.53784
# Generation 283: Best Value = 0.53784
# Generation 284: Best Value = 0.53784
# Generation 285: Best Value = 0.53784
# Generation 286: Best Value = 0.40950
# Generation 287: Best Value = 0.40950
# Generation 288: Best Value = 0.40950
# Generation 289: Best Value = 0.40950
# Generation 290: Best Value = 0.53784
# Generation 291: Best Value = 0.53784
# Generation 292: Best Value = 0.53784
# Generation 293: Best Value = 0.53784
# Generation 294: Best Value = 0.53784
# Generation 295: Best Value = 0.53784
# Generation 296: Best Value = 0.53784
# Generation 297: Best Value = 0.53784
# Generation 298: Best Value = 0.53784
# Generation 299: Best Value = 0.53784
# Generation 300: Best Value = 0.53784
# Generation 301: Best Value = 0.49244
# Generation 302: Best Value = 0.49244
# Generation 303: Best Value = 0.49244
# Generation 304: Best Value = 0.35973
# Generation 305: Best Value = 0.35973
# Generation 306: Best Value = 0.35973
# Generation 307: Best Value = 0.35973
# Generation 308: Best Value = 0.35973
# Generation 309: Best Value = 0.35973
# Generation 310: Best Value = 0.35973
# Generation 311: Best Value = 0.35973
# Generation 312: Best Value = 0.35973
# Generation 313: Best Value = 0.35973
# Generation 314: Best Value = 0.35973
# Generation 315: Best Value = 0.35699
# Generation 316: Best Value = 0.35699
# Generation 317: Best Value = 0.35699
# Generation 318: Best Value = 0.35699
# Generation 319: Best Value = 0.35699
# Generation 320: Best Value = 0.35699
# Generation 321: Best Value = 0.35699
# Generation 322: Best Value = 0.35699
# Generation 323: Best Value = 0.35699
# Generation 324: Best Value = 0.35699
# Generation 325: Best Value = 0.35699
# Generation 326: Best Value = 0.35699
# Generation 327: Best Value = 0.35699
# Generation 328: Best Value = 0.35699
# Generation 329: Best Value = 0.35699
# Generation 330: Best Value = 0.35699
# Generation 331: Best Value = 0.35699
# Generation 332: Best Value = 0.34431
# Generation 333: Best Value = 0.35699
# Generation 334: Best Value = 0.35699
# Generation 335: Best Value = 0.35699
# Generation 336: Best Value = 0.35699
# Generation 337: Best Value = 0.35699
# Generation 338: Best Value = 0.35699
# Generation 339: Best Value = 0.35699
# Generation 340: Best Value = 0.35699
# Generation 341: Best Value = 0.35699
# Generation 342: Best Value = 0.35699
# Generation 343: Best Value = 0.35699
# Generation 344: Best Value = 0.35699
# Generation 345: Best Value = 0.35699
# Generation 346: Best Value = 0.35699
# Generation 347: Best Value = 0.35699
# Generation 348: Best Value = 0.35699
# Generation 349: Best Value = 0.35699
# Generation 350: Best Value = 0.35699
# Generation 351: Best Value = 0.35699
# Generation 352: Best Value = 0.35699
# Generation 353: Best Value = 0.35699
# Generation 354: Best Value = 0.35699
# Generation 355: Best Value = 0.32921
# Generation 356: Best Value = 0.35699
# Generation 357: Best Value = 0.35699
# Generation 358: Best Value = 0.35699
# Generation 359: Best Value = 0.35699
# Generation 360: Best Value = 0.35699
# Generation 361: Best Value = 0.35699
# Generation 362: Best Value = 0.35699
# Generation 363: Best Value = 0.35699
# Generation 364: Best Value = 0.35699
# Generation 365: Best Value = 0.35699
# Generation 366: Best Value = 0.35699
# Generation 367: Best Value = 0.33155
# Generation 368: Best Value = 0.32600
# Generation 369: Best Value = 0.32600
# Generation 370: Best Value = 0.32600
# Generation 371: Best Value = 0.32600
# Generation 372: Best Value = 0.21967
# Generation 373: Best Value = 0.32288
# Generation 374: Best Value = 0.32288
# Generation 375: Best Value = 0.32288
# Generation 376: Best Value = 0.32288
# Generation 377: Best Value = 0.32288
# Generation 378: Best Value = 0.32288
# Generation 379: Best Value = 0.32288
# Generation 380: Best Value = 0.32288
# Generation 381: Best Value = 0.32288
# Generation 382: Best Value = 0.32288
# Generation 383: Best Value = 0.32288
# Generation 384: Best Value = 0.32288
# Generation 385: Best Value = 0.32288
# Generation 386: Best Value = 0.32288
# Generation 387: Best Value = 0.32288
# Generation 388: Best Value = 0.32288
# Generation 389: Best Value = 0.32288
# Generation 390: Best Value = 0.32288
# Generation 391: Best Value = 0.32288
# Generation 392: Best Value = 0.32288
# Generation 393: Best Value = 0.32288
# Generation 394: Best Value = 0.32288
# Generation 395: Best Value = 0.32288
# Generation 396: Best Value = 0.32288
# Generation 397: Best Value = 0.32288
# Generation 398: Best Value = 0.32217
# Generation 399: Best Value = 0.31138
# Generation 400: Best Value = 0.32288
# Generation 401: Best Value = 0.32288
# Generation 402: Best Value = 0.32288
# Generation 403: Best Value = 0.32288
# Generation 404: Best Value = 0.32288
# Generation 405: Best Value = 0.32288
# Generation 406: Best Value = 0.30845
# Generation 407: Best Value = 0.31500
# Generation 408: Best Value = 0.32288
# Generation 409: Best Value = 0.32288
# Generation 410: Best Value = 0.31860
# Generation 411: Best Value = 0.31860
# Generation 412: Best Value = 0.31860
# Generation 413: Best Value = 0.26640
# Generation 414: Best Value = 0.31860
# Generation 415: Best Value = 0.31860
# Generation 416: Best Value = 0.31860
# Generation 417: Best Value = 0.31860
# Generation 418: Best Value = 0.31860
# Generation 419: Best Value = 0.31860
# Generation 420: Best Value = 0.31860
# Generation 421: Best Value = 0.31860
# Generation 422: Best Value = 0.31860
# Generation 423: Best Value = 0.31860
# Generation 424: Best Value = 0.31860
# Generation 425: Best Value = 0.31860
# Generation 426: Best Value = 0.31860
# Generation 427: Best Value = 0.31860
# Generation 428: Best Value = 0.31860
# Generation 429: Best Value = 0.31860
# Generation 430: Best Value = 0.31860
# Generation 431: Best Value = 0.31860
# Generation 432: Best Value = 0.31860
# Generation 433: Best Value = 0.31860
# Generation 434: Best Value = 0.31860
# Generation 435: Best Value = 0.34343
# Generation 436: Best Value = 0.34343
# Generation 437: Best Value = 0.34343
# Generation 438: Best Value = 0.33139
# Generation 439: Best Value = 0.31860
# Generation 440: Best Value = 0.31860
# Generation 441: Best Value = 0.31860
# Generation 442: Best Value = 0.31860
# Generation 443: Best Value = 0.31860
# Generation 444: Best Value = 0.31860
# Generation 445: Best Value = 0.31860
# Generation 446: Best Value = 0.31860
# Generation 447: Best Value = 0.31860
# Generation 448: Best Value = 0.31860
# Generation 449: Best Value = 0.31860
# Generation 450: Best Value = 0.31860
# Generation 451: Best Value = 0.31860
# Generation 452: Best Value = 0.31860
# Generation 453: Best Value = 0.31860
# Generation 454: Best Value = 0.31860
# Generation 455: Best Value = 0.34343
# Generation 456: Best Value = 0.25134
# Generation 457: Best Value = 0.34343
# Generation 458: Best Value = 0.34343
# Generation 459: Best Value = 0.34531
# Generation 460: Best Value = 0.34531
# Generation 461: Best Value = 0.34531
# Generation 462: Best Value = 0.34531
# Generation 463: Best Value = 0.34531
# Generation 464: Best Value = 0.34531
# Generation 465: Best Value = 0.34531
# Generation 466: Best Value = 0.34531
# Generation 467: Best Value = 0.34531
# Generation 468: Best Value = 0.34531
# Generation 469: Best Value = 0.34531
# Generation 470: Best Value = 0.34531
# Generation 471: Best Value = 0.34531
# Generation 472: Best Value = 0.34531
# Generation 473: Best Value = 0.34531
# Generation 474: Best Value = 0.34531
# Generation 475: Best Value = 0.34531
# Generation 476: Best Value = 0.34531
# Generation 477: Best Value = 0.34531
# Generation 478: Best Value = 0.34531
# Generation 479: Best Value = 0.34531
# Generation 480: Best Value = 0.34531
# Generation 481: Best Value = 0.34531
# Generation 482: Best Value = 0.34531
# Generation 483: Best Value = 0.34531
# Generation 484: Best Value = 0.34531
# Generation 485: Best Value = 0.34531
# Generation 486: Best Value = 0.34531
# Generation 487: Best Value = 0.34531
# Generation 488: Best Value = 0.34531
# Generation 489: Best Value = 0.34531
# Generation 490: Best Value = 0.34531
# Generation 491: Best Value = 0.34531
# Generation 492: Best Value = 0.34531
# Generation 493: Best Value = 0.34531
# Generation 494: Best Value = 0.34531
# Generation 495: Best Value = 0.34531
# Generation 496: Best Value = 0.34531
# Generation 497: Best Value = 0.34531
# Generation 498: Best Value = 0.34531
# Generation 499: Best Value = 0.34531
# Generation 500: Best Value = 0.34531
#
# Final Best Solution:
# Genes: [0.37075091924379766, -0.23653661806836546, 0.020809139240634877, 0.2205485795065476, -0.21483044755642666, -0.04751087900227624, -0.12182781417202904, 0.045605826740818145, 0.03182324378767376, 0.1910008455308967], Value: 0.34531
